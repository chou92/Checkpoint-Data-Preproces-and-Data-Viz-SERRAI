# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("darkgrid")

# %%
TITANIC_file = "titanic-passengers"
TITANIC_data = pd.read_csv("titanic-passengers.csv", sep=';')
TITANIC_data
# Out:
#      PassengerId Survived  Pclass  \
# 0            343       No       2
# 1             76       No       3
# 2            641       No       3
# 3            568       No       3
# 4            672       No       1
# ..           ...      ...     ...
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex   Age  SibSp  \
# 0                           Collander, Mr. Erik Gustaf    male  28.0      0
# 1                              Moen, Mr. Sigurd Hansen    male  25.0      0
# 2                               Jensen, Mr. Hans Peder    male  20.0      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0      0
# 4                               Davidson, Mr. Thornton    male  31.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ### HEAD ELEMENTS DISPLAYED

# %%
TITANIC_data.head(10)
# Out:
#    PassengerId Survived  Pclass  \
# 0          343       No       2
# 1           76       No       3
# 2          641       No       3
# 3          568       No       3
# 4          672       No       1
# 5          105       No       3
# 6          576       No       3
# 7          382      Yes       3
# 8          228       No       3
# 9          433      Yes       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                         Collander, Mr. Erik Gustaf    male  28.0      0
# 1                            Moen, Mr. Sigurd Hansen    male  25.0      0
# 2                             Jensen, Mr. Hans Peder    male  20.0      0
# 3        Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0      0
# 4                             Davidson, Mr. Thornton    male  31.0      1
# 5                     Gustafsson, Mr. Anders Vilhelm    male  37.0      2
# 6                               Patchett, Mr. George    male  19.0      0
# ...

# %% [markdown]
# # GENERAL INFORMATION

# %%
data = TITANIC_data [["Survived","Pclass", "Name", "Sex", "Age", "SibSp", "Parch", "Ticket", "Fare", "Cabin", "Embarked"]]
data
# Out:
#     Survived  Pclass                                               Name  \
# 0         No       2                         Collander, Mr. Erik Gustaf
# 1         No       3                            Moen, Mr. Sigurd Hansen
# 2         No       3                             Jensen, Mr. Hans Peder
# 3         No       3        Palsson, Mrs. Nils (Alma Cornelia Berglund)
# 4         No       1                             Davidson, Mr. Thornton
# ..       ...     ...                                                ...
# 886      Yes       2                Nasser, Mrs. Nicholas (Adele Achem)
# 887       No       3                              Sirayanian, Mr. Orsen
# 888       No       3                                Cacic, Miss. Marija
# 889       No       3                   Petroff, Mr. Pastcho ("Pentcho")
# 890      Yes       2  Phillips, Miss. Kate Florence ("Mrs Kate Louis...
#
#         Sex   Age  SibSp  Parch      Ticket     Fare  Cabin Embarked
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    object
#  1   Pclass    891 non-null    int64
#  2   Name      891 non-null    object
#  3   Sex       891 non-null    object
#  4   Age       714 non-null    float64
#  5   SibSp     891 non-null    int64
#  6   Parch     891 non-null    int64
#  7   Ticket    891 non-null    object
#  8   Fare      891 non-null    float64
#  9   Cabin     204 non-null    object
#  10  Embarked  889 non-null    object
# dtypes: float64(2), int64(3), object(6)
# memory usage: 76.7+ KB

# %% [markdown]
# # 1. PREPROCESSING PHASE

# %% [markdown]
# ![PHASE%201.PNG](attachment:PHASE%201.PNG)

# %% [markdown]
# # DATA CLEANING

# %% [markdown]
# ### NAN VALUE  / Missing Values

# %%
data.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64

# %% [markdown]
# ![NAN%20VALUES%20.png](attachment:NAN%20VALUES%20.png)

# %% [markdown]
# ### REPLACING MISSING DATA WITH MEANS  FOR Age Column

# %%
dfrd.head(10)
# Out:
#   Survived  Pclass                                               Name     Sex  \
# 0       No       2                         Collander, Mr. Erik Gustaf    male
# 1       No       3                            Moen, Mr. Sigurd Hansen    male
# 2       No       3                             Jensen, Mr. Hans Peder    male
# 3       No       3        Palsson, Mrs. Nils (Alma Cornelia Berglund)  female
# 4       No       1                             Davidson, Mr. Thornton    male
# 5       No       3                     Gustafsson, Mr. Anders Vilhelm    male
# 6       No       3                               Patchett, Mr. George    male
# 7      Yes       3                        Nakid, Miss. Maria ("Mary")  female
# 8       No       3                    Lovell, Mr. John Hall ("Henry")    male
# 9      Yes       2  Louch, Mrs. Charles Alexander (Alice Adelaide ...  female
#
#     Age  SibSp  Parch      Ticket     Fare  Cabin Embarked
# ...

# %%
dfrd['Age'].fillna(dfrd['Age'].mean(),inplace=True)
dfrd.head(5)
# remplacer les données manquantes par des moyennes
# Out:
#   Survived  Pclass                                         Name     Sex   Age  \
# 0       No       2                   Collander, Mr. Erik Gustaf    male  28.0
# 1       No       3                      Moen, Mr. Sigurd Hansen    male  25.0
# 2       No       3                       Jensen, Mr. Hans Peder    male  20.0
# 3       No       3  Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0
# 4       No       1                       Davidson, Mr. Thornton    male  31.0
#
#    SibSp  Parch      Ticket     Fare  Cabin Embarked
# 0      0      0      248740  13.0000    NaN        S
# 1      0      0      348123   7.6500  F G73        S
# 2      0      0      350050   7.8542    NaN        S
# 3      0      4      349909  21.0750    NaN        S
# 4      1      0  F.C. 12750  52.0000    B71        S

# %% [markdown]
# ### REPLACING MISSING DATA  FOR Cabin Column

# %% [markdown]
# ### Remplacer par les valeurs les plus fréquantes

# %%
dfrd['Cabin'].value_counts()
# Out:
# C23 C25 C27    4
# G6             4
# B96 B98        4
# C22 C26        3
# F33            3
#               ..
# D45            1
# C111           1
# E38            1
# E49            1
# D50            1
# Name: Cabin, Length: 147, dtype: int64

# %%
dfrd['Cabin'].fillna('C23',inplace=True)
dfrd.head(5)
# Out:
#   Survived  Pclass                                         Name     Sex   Age  \
# 0       No       2                   Collander, Mr. Erik Gustaf    male  28.0
# 1       No       3                      Moen, Mr. Sigurd Hansen    male  25.0
# 2       No       3                       Jensen, Mr. Hans Peder    male  20.0
# 3       No       3  Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0
# 4       No       1                       Davidson, Mr. Thornton    male  31.0
#
#    SibSp  Parch      Ticket     Fare  Cabin Embarked
# 0      0      0      248740  13.0000    C23        S
# 1      0      0      348123   7.6500  F G73        S
# 2      0      0      350050   7.8542    C23        S
# 3      0      4      349909  21.0750    C23        S
# 4      1      0  F.C. 12750  52.0000    B71        S

# %% [markdown]
# ### Using OrdinalEncoder to transform categorical values

# %% [markdown]
# ![valeurs%20categorielles.png](attachment:valeurs%20categorielles.png)

# %%
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()
dfrd['Survived']=encoder.fit_transform(dfrd['Survived'])
dfrd['Sex']=encoder.fit_transform(dfrd['Sex'])
dfrd.head(10)
# Out:
#    Survived  Pclass                                               Name  Sex  \
# 0         0       2                         Collander, Mr. Erik Gustaf    1
# 1         0       3                            Moen, Mr. Sigurd Hansen    1
# 2         0       3                             Jensen, Mr. Hans Peder    1
# 3         0       3        Palsson, Mrs. Nils (Alma Cornelia Berglund)    0
# 4         0       1                             Davidson, Mr. Thornton    1
# 5         0       3                     Gustafsson, Mr. Anders Vilhelm    1
# 6         0       3                               Patchett, Mr. George    1
# 7         1       3                        Nakid, Miss. Maria ("Mary")    0
# 8         0       3                    Lovell, Mr. John Hall ("Henry")    1
# 9         1       2  Louch, Mrs. Charles Alexander (Alice Adelaide ...    0
#
#     Age  SibSp  Parch      Ticket     Fare  Cabin Embarked
# 0  28.0      0      0      248740  13.0000     63        S
# ...

# %% [markdown]
# # 2. VISUALIZATION PHASE

# %% [markdown]
# ![PHASE%202%20PARTIE%201.PNG](attachment:PHASE%202%20PARTIE%201.PNG)

# %% [markdown]
# ![PHASE%202%20PARTIE%202.PNG](attachment:PHASE%202%20PARTIE%202.PNG)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Studying the distribution of the most important features based on the understanding of the dataset and the problem.

# %% [markdown]
# ### seaborn.pairplot

# %%
sns.pairplot(data)

# %% [markdown]
# ### Age Visualization with Seaborn / statistical data visualization

# %%
sns.distplot(dfrd['Age'],bins=10,kde=True,color='blue')
# Out:
# C:\Users\Lenovo\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
plt.title('passenger classes  categories visualization')
plt.xlabel('Classes')
plt.ylabel('Passengers')
vc = dfrd['Pclass'].value_counts()
vc.plot.bar(rot=30)
# Out:
# <AxesSubplot:title={'center':'passenger classes  categories visualization'}, xlabel='Classes', ylabel='Passengers'>

# %% [markdown]
# ### Commentaire: la 3eme classe est la plus importante parmi les gatégories des passagers.

# %%
plt.title('passengers gender ')
plt.xlabel('Sex')
plt.ylabel('Passengers')
vc = dfrd['Sex'].value_counts()
vc.plot.bar(rot=30)
# Out:
# <AxesSubplot:title={'center':'passengers gender '}, xlabel='Sex', ylabel='Passengers'>

# %% [markdown]
# ### Commentaire: le nombre d'homme (1) est plus important (presque le double) que celui des femmes (0)

# %%
plt.title('Survived Vs. non-survivors passengers')
plt.xlabel('Survived ')
plt.ylabel('Passengers Number')
vc = dfrd['Survived'].value_counts()
vc.plot.bar(rot=30)
# Out:
# <AxesSubplot:title={'center':'Survived Vs. non-survivors passengers'}, xlabel='Survived ', ylabel='Passengers Number'>

# %% [markdown]
# ### Commentaire: le nombre des survivants (1) est moins important par rapport aux non-survivants (0)

# %%
sns.distplot(dfrd['Fare'],bins=10,kde=True,color='blue')
# Out:
# C:\Users\Lenovo\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Fare', ylabel='Density'>

# %% [markdown]
# ### Commentaire: On remarque  logiquement que le nombre de la classe 3 (qui est la troisieme classe) est la plus dense et qui paie moin cher.

# %% [markdown]
# ### Remarque: Malheureusement pour certaines variables, je n'ai pas pu les expliquer car elles restent ambigues  / they remain ambiguous = "SibSp"	"Parch"

# %% [markdown]
# #  CORRELATION BETWEEN Sex and Age : Corr1

# %%
corr1=sns.FacetGrid(dfrd,col='Sex')
corr1.map(plt.hist,'Age',bins=10,color='green')

# %% [markdown]
# ### Commentaire Corr 1: la catégorie Homme (1) reste importante que la catégorie femme (0) mais de la meme distribution des catégorie d'Age.

# %% [markdown]
# #  CORRELATION BETWEEN Sex, Age and the Survival of the individuals: Corr 2

# %%
corr2 = sns.FacetGrid(dfrd, row="Sex", col="Survived")
corr2.map(plt.hist, "Age",bins=10,color='red')
corr2.add_legend()

# %% [markdown]
# ## Commentaire Corr 2:
# ### la catégorie des femmes(0) enregistre la catégorie qui est peu présente dans TITANIC, mais qui sont la majorité des survivants (1), biensur par rapport aux nombre des passagers femmes.
# ### la catégorie des Hommes ( 1) contrairement aux femmes, c'est la catégorie qui avec une forte présence qui enregistre le nombre le plus important des non-survivants (0), avec des survivants (1) homme (1) moins importante par rapport aux femmes.
# ## Remarque: On peut dire que les enfants( de 0 à 10 ans)  et les femmes étaient les catégories favorisées au moment du lsauvetage.

# %%
Corr3=sns.FacetGrid(dfrd,col='Pclass')
Corr3.map(plt.hist,'Fare',bins=5,color='orange')

# %% [markdown]
# ## Commentaire Corr 3:
# ### la classe 1 fait le double de la classe 2 et la moitié de la classe 3 et qui paie le plus.
# ### la classe 3 marque une forte présence mais qui paie moin.

# %%
corr4 = sns.FacetGrid(dfrd, row="Pclass", col="Survived")
corr4.map(plt.hist, "Fare",bins=5,color='purple')
corr4.add_legend()

# %% [markdown]
# ## Commentaire Corr4:
# ### pour compléter la corr 3, On remarque à travers Corr 4 que la classe 1 font la catégorie des survivants la plus importante, contrairement à la classe 3 qui font la majorité des non-survivants. la classe 2 sont la cartégorie qui enregistre présque le meme nombre des survivants que les non-survivants avec une légère différence + de ce dernier.

# %%
def plot_correlation_map( df ):

    corr = df.corr()

    s , ax = plt.subplots( figsize =( 12 , 10 ) )

    cmap = sns.diverging_palette( 220 , 10 , as_cmap = True )

    s = sns.heatmap(

        corr, 

        cmap = cmap,

        square=True, 

        cbar_kws={ 'shrink' : .9 }, 

        ax=ax, 

        annot = True, 

        annot_kws = { 'fontsize' : 12 }

        )

# %%
plot_correlation_map(dfrd)

# %% [markdown]
# ##  correlation_map
# ### This analysis is one of the methods used to decide which features affect the target variable the most, and in turn, get used in predicting this target variable. In other words, it’s a commonly-used method for feature selection in machine learning. source: https://heartbeat.fritz.ai/seaborn-heatmaps-13-ways-to-customize-correlation-matrix-visualizations-f1c49c816f07
#
# ### Values closer to zero means there is no linear trend between the two variables ( ex: Pclass and Parch). The close to 1 the correlation is the more positively correlated they are ( ex: SibSp and Parch) ; that is as one increases so does the other and the closer to 1 the stronger this relationship is.
# ### ex negative correlation: Pclass and Fare.

# %% [markdown]
# ##  The groupby function combined with the mean() to view the relation between Pclass and survived

# %%
dfrd[["Pclass", "Survived"]].groupby(["Pclass"], as_index=True).mean()
# Out:
#         Survived
# Pclass
# 1       0.629630
# 2       0.472826
# 3       0.242363

# %% [markdown]
# ### Commentaire:
# ### on remarque que la class 1 enregistre plus de survivants contrairement à la classe 3.

# %%
dfrd
# Out:
#      Survived  Pclass                                               Name  Sex  \
# 0           0       2                         Collander, Mr. Erik Gustaf    1
# 1           0       3                            Moen, Mr. Sigurd Hansen    1
# 2           0       3                             Jensen, Mr. Hans Peder    1
# 3           0       3        Palsson, Mrs. Nils (Alma Cornelia Berglund)    0
# 4           0       1                             Davidson, Mr. Thornton    1
# ..        ...     ...                                                ...  ...
# 886         1       2                Nasser, Mrs. Nicholas (Adele Achem)    0
# 887         0       3                              Sirayanian, Mr. Orsen    1
# 888         0       3                                Cacic, Miss. Marija    0
# 889         0       3                   Petroff, Mr. Pastcho ("Pentcho")    1
# 890         1       2  Phillips, Miss. Kate Florence ("Mrs Kate Louis...    0
#
# ...

# %% [markdown]
# ### Creation of new column called Title which contains the appropriate Title for each individual ( hint: extract the title from the column Names)

# %%
data['Title'] = data.Name.str.extract(' ([A-Za-z]+)\.', expand=False)
new=data['Title']
new.value_counts()
# Out:
# Mr          517
# Miss        182
# Mrs         125
# Master       40
# Dr            7
# Rev           6
# Col           2
# Mlle          2
# Major         2
# Ms            1
# Mme           1
# Lady          1
# Capt          1
# Sir           1
# Don           1
# Jonkheer      1
# Countess      1
# Name: Title, dtype: int64
